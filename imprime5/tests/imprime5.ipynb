# %%
"""
Programa imprime5
Descrição: Este programa que imprima os numeros inteiros de 1 a 5.
Autor: Nelson
Data: 24/03/2026
Versão 0.0.1
"""
# Out:
# '\nPrograma imprime5\nDescrição: Este programa que imprima os numeros inteiros de 1 a 5.\nAutor: Nelson\nData: 24/03/2026\nVersão 0.0.1\n'

# %%
# Alocação de memória

i = 0

# %%
# Entrada de dados

# %%
# Processamento de dados

# %%
# Saída de dados

while i < 5:
    print(i+1)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
